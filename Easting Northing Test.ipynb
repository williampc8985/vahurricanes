# %%
import pandas as pd
import convertbng
from convertbng.util import convert_bng, convert_lonlat

# %%
pd.__version__
# Out:
# '1.0.5'

# %%
data = pd.read_csv('BUFFERJAMES.csv').astype(float)
print(data)
# Out:
#          Easting     Northing
# 0   -8533886.828  4254908.353
# 1   -8533895.398  4254908.616
# 2   -8540346.047  4255258.178
# 3   -8541002.516  4255309.208
# 4   -8541379.587  4255317.157
# ..           ...          ...
# 774 -8519754.991  4255201.086
# 775 -8522846.120  4255012.851
# 776 -8522849.460  4255012.685
# 777 -8524951.422  4254924.510
# 778 -8533886.828  4254908.353
#
# [779 rows x 2 columns]

# %%
pd.DataFrame(data, columns = ['Easting','Northing'])
# Out:
#          Easting     Northing
# 0   -8533886.828  4254908.353
# 1   -8533895.398  4254908.616
# 2   -8540346.047  4255258.178
# 3   -8541002.516  4255309.208
# 4   -8541379.587  4255317.157
# ..           ...          ...
# 774 -8519754.991  4255201.086
# 775 -8522846.120  4255012.851
# 776 -8522849.460  4255012.685
# 777 -8524951.422  4254924.510
# 778 -8533886.828  4254908.353
#
# [779 rows x 2 columns]

# %%
df["Easting"]
# Out:
# 0     -8533886.828
# 1     -8533895.398
# 2     -8540346.047
# 3     -8541002.516
# 4     -8541379.587
#           ...
# 774   -8519754.991
# 775   -8522846.120
# 776   -8522849.460
# 777   -8524951.422
# 778   -8533886.828
# Name: Easting, Length: 779, dtype: float64

# %%
eastings = df['Easting']
northings = df['Northing']
#print(eastings,northings)
res_list_en = convert_lonlat(eastings, northings)

# %%
res_list_en
# Out:
# ([nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
# ...
